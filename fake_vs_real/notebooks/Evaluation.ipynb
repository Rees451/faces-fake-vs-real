# %% [markdown]
# ## Evaluation of trained models

# %%
import sys
data_dir = '../data'
src_path = '../src'
test_dir = '../data/processed/sf/all/test'
if src_path not in sys.path:
    sys.path.append(src_path)

# %%
import loading as ld
import trained_model as tm
import importlib
importlib.reload(tm)
# Out:
# <module 'trained_model' from '../src/trained_model.py'>

# %%
test = ld.load_test_generator(test_dir)
# Out:
# Found 205 images belonging to 2 classes.

# %% [markdown]
# ## Models

# %% [markdown]
# I wrote the class `TrainedModel` to load tensorflow models from the weights caluclated when training, view the source code [here](../src/trained_model)

# %%
clf = tm.TrainedModel('c3_lt', test)

# %%
clf.plot_training()
clf.classification_report()
clf.conf_matrix()
clf.test_on_difficulty(tests=1000)
# Out:
#               precision    recall  f1-score   support
#
#         fake       0.39      0.43      0.41        96
#         real       0.45      0.41      0.43       109
#
#     accuracy                           0.42       205
#    macro avg       0.42      0.42      0.42       205
# weighted avg       0.42      0.42      0.42       205
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-062b485c1b47> in <module>
#       2 clf.classification_report()
#       3 clf.conf_matrix()
# ----> 4 clf.test_on_difficulty(tests=1000)
#
# ~/Google Drive/GA/Capstone/fake_vs_real/src/trained_model.py in test_on_difficulty(self, tests)
#      67     def test_on_difficulty(self, tests=1000):
#      68
# ---> 69         fake_paths, real_paths = self._get_paths(test_dir, dif, n=tests)
#      70
#      71         fake_imgs = np.zeros((tests, ) + img_shape)
#
# AttributeError: 'TrainedModel' object has no attribute '_get_paths'
